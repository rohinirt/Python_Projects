# %%
import pandas as pd
import nltk #Natural Language Toolkit used to work with human language data
from nltk.corpus import stopwords #stopwords ignore common words in english
from nltk.tokenize import word_tokenize #used to tokenize (split) text into individual words
from nltk.probability import FreqDist #compute the frequency distribution of a list of words.

# Download the 'punkt' resource
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ankit's
# [nltk_data]     PREDATOR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Ankit's
# [nltk_data]     PREDATOR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install numpy
# !pip install cycler
# !pip install pyparsing
# !pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\Rohini Personal\ana\Lib\site-packages)
# ...
#   Using cached matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import warnings
#import matplotlib.pyplot as plt

#warnings.filterwarnings('ignore')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows',None)
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv(r"D:\Rohini Personal\Portfolio Builder-20231213T063832Z-001\5. EducationJob – LinkedIn Data Analyst Jobs\linkedin_jobs.csv")

# %%
#get Basic statistics
df.describe()
# Out:
#              Job_ID     Avg Salary
# count  1.500000e+02     150.000000
# mean   3.682792e+09  143985.193333
# std    3.549511e+07   71210.392478
# min    3.509818e+09      18.000000
# 25%    3.676130e+09  108000.000000
# 50%    3.693789e+09  169063.000000
# 75%    3.709925e+09  191837.500000
# max    3.713367e+09  285000.000000

# %%
#check for missing values
df.isnull().sum()
# Out:
# Job_ID              0
# title               0
# company             0
# location            0
# Mode                0
# Min Salary         29
# Max Salary         30
# Avg Salary          0
# Yr/Hr               0
# Type                0
# Level               0
# Industry            0
# Job Description     0
# dtype: int64

# %%
#datatype of each column
df.dtypes
# Out:
# Job_ID              int64
# title              object
# company            object
# location           object
# Mode               object
# Min Salary         object
# Max Salary         object
# Avg Salary          int64
# Yr/Hr              object
# Type               object
# Level              object
# Industry           object
# Job Description    object
# dtype: object

# %%
#change the datatype
df['title'] = df['title'].astype(str)
df['company'] = df['company'].astype(str)
df['location'] = df['location'].astype(str)
df['Type'] = df['Type'].astype(str)
df['Level'] = df['Level'].astype(str)
df['Industry'] = df['Industry'].astype(str)
df['Job Description'] = df['Job Description'].astype(str)
df['Avg Salary'] = df['Avg Salary'].astype(int)

# %% [markdown]
# # Text Analysis

# %% [markdown]
# ### 1. Job Description

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
text = ' '.join(df['Job Description'])
tokens = word_tokenize(text) # Tokenize the text into words
stop_words = set(stopwords.words('english')) #create a set of common words in english
filtered_tokens = [word for word in tokens if word.lower() not in stop_words] #remove stopwords from list of tokens
freq_dist = FreqDist(filtered_tokens) #frequency distribution of Filtered tokens

#WORDCLOUD of keywords in Job Description
from wordcloud import WordCloud
wordcloud = WordCloud(width=1200, height=600, max_words=200, background_color='white').generate_from_frequencies(freq_dist)
# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
 #print the frequency of all the keywords
for word, frequency in freq_dist.items():
    print(f"{word}: {frequency}")
# Out:
# Forge: 10
# NYSE: 2
# FRGE: 1
# know: 53
# team: 391
# greatest: 6
# asset: 4
# technology: 98
# innovators: 1
# private: 12
# market: 26
# vision: 62
# deliver: 48
# richer: 1
# future: 78
# everyone: 11
# live: 14
# values: 29
# bold: 3
# humble: 2
# accountable: 6
# experience: 622
# value: 21
# brings: 3
# world: 72
# every: 56
# day: 60
# helping: 15
# teams: 194
# behind: 5
# innovations: 2
# generation: 11
# space: 7
# travel: 31
# planet-saving: 1
# plant-based: 1
# nutrition: 2
# mission: 45
# empower: 18
# people: 69
# exercise: 1
# ownership: 5
# ’: 419
# leading: 28
# companies: 33
# via: 20
# world-class: 5
# platform: 54
# access: 29
# largest: 7
# network: 68
# buyers: 2
# sellers: 9
# liquidity: 2
# solutions: 186
# exclusive: 1
# data: 534
# insights: 23
# custody: 1
# offering: 6
# vibrant: 3
# marketplace: 9
# goal: 17
# build: 108
# best-in-class: 2
# infrastructure: 45
# power: 28
# global: 61
# transparent: 1
# accessible: 73
# seamless: 3
# employees: 164
# ...

# %%
#print in descending order
for word, frequency in sorted(freq_dist.items(), key=lambda item: item[1], reverse=True):
    print(f"{word}: {frequency}")
# Out:
# experience: 622
# data: 534
# ’: 419
# team: 391
# Rivian: 371
# employment: 344
# including: 332
# Experience: 307
# may: 306
# Data: 278
# information: 275
# development: 270
# work: 264
# skills: 254
# $: 252
# software: 249
# status: 227
# application: 222
# design: 215
# years: 203
# gender: 196
# teams: 194
# services: 193
# -: 193
# solutions: 186
# opportunity: 185
# new: 180
# business: 179
# process: 173
# disability: 168
# Apple: 168
# role: 167
# systems: 167
# system: 165
# employees: 164
# Candidate: 163
# security: 160
# &: 160
# working: 152
# related: 152
# products: 151
# company: 150
# support: 150
# applicable: 150
# law: 150
# test: 149
# benefits: 146
# tools: 143
# range: 138
# national: 137
# within: 135
# knowledge: 135
# age: 133
# compensation: 131
# technical: 130
# Personal: 130
# requirements: 129
# required: 128
# us: 128
# customers: 128
# based: 126
# and/or: 124
# protected: 124
# laws: 123
# engineering: 123
# environment: 120
# location: 120
# ...

# %% [markdown]
# ###### Top 10 keywords in Job Description

# %%
# Display the top 10 keywords and their frequencies
print("Top 10 keywords and their frequencies:")
for word, frequency in freq_dist.most_common(20):
    print(f"{word}: {frequency}")
# Out:
# Top 10 keywords and their frequencies:
# experience: 622
# data: 534
# ’: 419
# team: 391
# Rivian: 371
# employment: 344
# including: 332
# Experience: 307
# may: 306
# Data: 278
# information: 275
# development: 270
# work: 264
# skills: 254
# $: 252
# software: 249
# status: 227
# application: 222
# design: 215
# years: 203

# %% [markdown]
# ###

# %% [markdown]
# ### 2. Job Title

# %%
import string
title_text = ' '.join(df['title'])
title_text = title_text.translate(str.maketrans("", "", string.punctuation)) # remove punctuation symbols
title_tokens = word_tokenize(title_text) # Tokenize(split) the text into words
stop_words = set(stopwords.words('english')) #create a set of common words in english
title_filtered_tokens = [word for word in title_tokens if word.lower() not in stop_words] #remove stopwords from list of tokens
title_freq_dist = FreqDist(title_filtered_tokens) #frequency distribution of Filtered tokens

#WORDCLOUD of keywords
wordcloud = WordCloud(width=1200, height=600, max_words=200, background_color='white').generate_from_frequencies(title_freq_dist)
# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ###### Top 10 KeyWords in JobTitles

# %%
# Display the top 10 keywords and their frequencies in job titles
print("Top 10 keywords and their frequencies:")
for word, frequency in title_freq_dist.most_common(10):
    print(f"{word}: {frequency}")
# Out:
# Top 10 keywords and their frequencies:
# Engineer: 92
# Software: 38
# Sr: 31
# Data: 23
# Staff: 21
# Senior: 20
# Analyst: 18
# Integration: 9
# System: 8
# Learning: 8

# %% [markdown]
# ###

# %% [markdown]
# ### 3. Company

# %%
Company_text = ' '.join(df['company'])
Company_text = Company_text.translate(str.maketrans("", "", string.punctuation)) # remove punctuation symbols
Company_tokens = word_tokenize(Company_text) # Tokenize(split) the text into words
stop_words = set(stopwords.words('english')) #create a set of common words in english
Company_filtered_tokens = [word for word in Company_tokens if word.lower() not in stop_words] #remove stopwords from list of tokens
Company_freq_dist = FreqDist(Company_filtered_tokens) #frequency distribution of Filtered tokens

#WORDCLOUD of keywords
wordcloud = WordCloud(width=1200, height=600, max_words=200, background_color='white').generate_from_frequencies(Company_freq_dist)
# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ###### Top  10 Company Keywords

# %%
# Display the top 10 keywords and their frequencies in Companies
print("Top 10 keywords and their frequencies:")
for word, frequency in Company_freq_dist.most_common(10):
    print(f"{word}: {frequency}")
# Out:
# Top 10 keywords and their frequencies:
# Rivian: 32
# Apple: 13
# Supermicro: 13
# Talentifyio: 10
# Solutions: 5
# Adobe: 5
# Salesforce: 4
# Bayside: 4
# Health: 3
# Kaiser: 3

# %% [markdown]
# ### 4. Industry

# %%
Industry_text = ' '.join(df['Industry'])
Industry_text = Industry_text.translate(str.maketrans("", "", string.punctuation)) # remove punctuation symbols
Industry_tokens = word_tokenize(Industry_text) # Tokenize(split) the text into words
stop_words = set(stopwords.words('english')) #create a set of common words in english
Industry_filtered_tokens = [word for word in Industry_tokens if word.lower() not in stop_words] #remove stopwords from list of tokens
Industry_freq_dist = FreqDist(Industry_filtered_tokens) #frequency distribution of Filtered tokens

#WORDCLOUD of keywords
wordcloud = WordCloud(width=1200, height=600, max_words=200, background_color='white').generate_from_frequencies(Industry_freq_dist)
# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ###### Top 10 Keywords in Industries

# %%
# Display the top 10 keywords and their frequencies in Industry
print("Top 10 keywords and their frequencies:")
for word, frequency in Industry_freq_dist.most_common(20):
    print(f"{word}: {frequency}")
# Out:
# Top 10 keywords and their frequencies:
# Manufacturing: 71
# Motor: 34
# Vehicle: 34
# Software: 29
# Development: 29
# Computer: 19
# Hardware: 14
# Computers: 13
# Electronics: 13
# Services: 12
# Staffing: 12
# Recruiting: 12
# Hospitals: 8
# Health: 8
# Care: 8
# Consulting: 6
# Retail: 5
# Pharmaceutical: 4
# Network: 4
# Security: 4

# %% [markdown]
# ###

# %% [markdown]
# ### Descriptive Analysis

# %%
Median_Salary = df['Avg Salary'].median()
print(f"Median Salary: {Median_Salary}")
Mean_Salary = df['Avg Salary'].mean()
print(f"Mean Salary: {Mean_Salary}")
Mode_Salary = df['Avg Salary'].mode()[0]
print(f"Mode Salary: {Mode_Salary}")
# Out:
# Median Salary: 169063.0
# Mean Salary: 143985.19333333333
# Mode Salary: 169063

# %% [markdown]
# # Industry Analysis - (Salary Range)

# %%
df_hourly = df[df['Yr/Hr'] == 'Hourly']

# %%
df_yearly = df[df['Yr/Hr'] == 'Yearly']

# %% [markdown]
# #### Industries having Hourly Salary Jobs

# %%
ind_salary = df_hourly.groupby('Industry')['Avg Salary'].mean().sort_values(ascending=True)
plt.figure(figsize=(10, 6))
sns.boxplot(x='Avg Salary', y='Industry', data=df_hourly, order=ind_salary.index)
plt.xlabel('Industry')
plt.ylabel('Average Salary')
plt.title('Average Salary Range by Industry (Box Plot)')
plt.show()

# %% [markdown]
# ######  For Industries Paying Hourly Salary IT Services ranges in the top with average amount of Jobs Available follwed by Healthcare and Motor Vehicle Manufacturing

# %% [markdown]
# ###

# %% [markdown]
# #### Industries having Yearly Salary Jobs

# %%
industry_salary = df_yearly.groupby('Industry')['Avg Salary'].mean().sort_values(ascending=True)
plt.figure(figsize=(10, 6))
sns.boxplot(x='Avg Salary', y='Industry', data=df_yearly, order=industry_salary.index)
plt.xlabel('Industry')
plt.ylabel('Average Salary (USD)')
plt.title('Average Salary Range by Industry (Box Plot)')
plt.show()

# %% [markdown]
# ###### In the realm of yearly salaries, Pharmaceutical Manufacturing stood out with the most significant number of jobs offering salaries below 1.5L. The Computer and Electronics Manufacturing sector took the lead in offering the highest paying jobs, closely followed by the entertainment and medical industries. Notably, Software Development, Motor Vehicle, and Recruiting industries exhibited outliers, indicating that only a select few positions in these sectors surpassed the 2L salary mark.

# %% [markdown]
# #

# %% [markdown]
# ## Job Level - Average Salary And Number of Jobs

# %%
# Group by 'Level' and calculate mean salary and count of job titles
level_salary_jobs = df_yearly.groupby('Level').agg({'Avg Salary': 'mean', 'title': 'count'}).sort_values(by='Avg Salary', ascending=True)
# Reverse the order of levels
level_salary_jobs = level_salary_jobs[::-1]
# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 3))
# Plot average salary with reversed order
sns.barplot(x='Avg Salary', y=level_salary_jobs.index, data=level_salary_jobs, color='indigo', ax=ax1)
ax1.set_xlabel('Average Salary')
ax1.set_ylabel('Level')
ax1.set_title('Average Salary by Level')
for index, value in enumerate(level_salary_jobs['Avg Salary']):
    ax1.text(value, index, f'{value:.2f}', ha='left', va='center')

# Plot number of jobs with reversed order
ax2.barh(level_salary_jobs.index, level_salary_jobs['title'], color='orange')
ax2.set_xlabel('Number of Jobs')
ax2.set_ylabel('Level')
ax2.set_title('Number of Jobs by Level')
ax2.invert_yaxis()  # Reverse the y-axis order
for index, value in enumerate(level_salary_jobs['title']):
    ax2.text(value, index, str(value), ha='center', va='center')
#Remove borderes from chart
for ax in [ax1, ax2]:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### 74% of the Jobs are available for Mid-Senior-level follwed by Associate  and Entry-Level . As Obvious Associate Jobs are paid higher Salary than Mid-senior-level position followed by Entry-level jobs

# %% [markdown]
# #

# %% [markdown]
# # Company Analysis

# %% [markdown]
# ### 1.Top 10 Companies by Jobs Availability

# %%
company_Jobs = df.groupby('company')['title'].count().sort_values(ascending=False)
top_10c = company_Jobs.head(10)
# Plot the results in a horizontal bar chart
plt.figure(figsize=(20,6))
bars = plt.bar(top_10c.index, top_10c, color='indigo', label='Avg Salary')
for bar, count in zip(bars, top_10c):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f' {count}',
             ha='center', va='bottom', fontsize=12, color='black')
plt.xlabel('Number of Jobs')
plt.ylabel("Company")
plt.show()

# %% [markdown]
# ###### Rivian boasts a significantly larger number of job opportunities compared to the other companies in top 10 list

# %% [markdown]
# #

# %% [markdown]
# ### 2.Top 10 Companies by Average Salary

# %%
company_salary = df.groupby('company')['Avg Salary'].mean().sort_values(ascending=False)
top_10cs = company_salary.head(10)
# Plot the results in a horizontal bar chart
plt.figure(figsize=(20,6))
bars = plt.bar(top_10cs.index, top_10cs, color='indigo', label='Avg Salary')
for bar, salary in zip(bars, df['Avg Salary']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),f' {salary}',
             ha='center', va='bottom', fontsize=12, color='black')
plt.xlabel('Average Salary')
plt.ylabel("Company")
plt.show()

# %% [markdown]
# ###### Google ranks 10th in terms of job availability. However, the average salary for these positions is surprisingly higher as expected. Following Google, ServiceNow and Acceler8 Talent also exhibit elevated average salaries for their respective job openings

# %% [markdown]
# #

# %% [markdown]
# ### Top 10 Locations by Jobs Available

# %%
Location_Jobs = df.groupby('location')['title'].count().sort_values(ascending=False)
top_10l = Location_Jobs.head(10)
# Plot the results in a horizontal bar chart
plt.figure(figsize=(18, 6))
bars = plt.bar(top_10l.index, top_10l, color='indigo',width =0.6 )
# Annotate the bars with job counts
for bar, count in zip(bars, top_10l):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f' {count}',
             ha='center', va='bottom', fontsize=12, color='black')
plt.xlabel('Number of Jobs')
plt.ylabel("location")
plt.show()

# %% [markdown]
# ### Average Salary by Jobs Type

# %% [markdown]
# ### 1)For Hourly Paying Jobs

# %%
Type_Jobs = df_hourly.groupby('Type')['Avg Salary'].mean().sort_values(ascending=False)
# Plot the results in a horizontal bar chart
plt.figure(figsize=(6, 3))
bars = plt.bar(Type_Jobs.index, Type_Jobs, color='indigo',width =0.4 )
for bar, salary in zip(bars, df['Avg Salary']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),f' {salary}',
             ha='center', va='bottom', fontsize=8, color='black')
plt.xlabel('Number of Jobs')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ###### For jobs payed hourly basis, contract-based positions often receive higher pay than their full-time counterparts. Conversely, internships tend to offer higher compensation compared to part-time roles.

# %% [markdown]
# #

# %% [markdown]
# ### 2. For Yearly Paying Jobs

# %%
Type_Jobs = df_yearly.groupby('Type')['Avg Salary'].mean().sort_values(ascending=False)
# Plot the results in a horizontal bar chart
plt.figure(figsize=(6, 3))
bars = plt.bar(Type_Jobs.index, Type_Jobs, color='indigo',width =0.4 )
for bar, salary in zip(bars, df['Avg Salary']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),f' {salary}',
             ha='center', va='bottom', fontsize=8, color='black', fontweight='bold')
plt.xlabel('Number of Jobs')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Distribution of Jobs by Working Mode

# %%
# Count the occurrences of each mode
mode_counts = df['Mode'].value_counts()
# Create a donut chart
plt.figure(figsize=(3, 3))
# Outer ring (pie chart)
plt.pie(mode_counts, labels=mode_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'], wedgeprops=dict(width=0.4, edgecolor='w'))
# Inner circle (donut hole)
center_circle = plt.Circle((0, 0), 0.3, color='white', fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
# Add title
plt.title('Distribution of Work Modes')
# Show the plot
plt.show()

# %% [markdown]
# ### Distribution of jobs by  Type

# %%
# Count the occurrences of each mod
Type_counts = df['Type'].value_counts()
# Create a donut chart
plt.figure(figsize=(6, 6))
# Outer ring (pie chart)
plt.pie(Type_counts, labels=Type_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightcoral', 'lightgreen','red','yellow'], wedgeprops=dict(width=0.4, edgecolor='w'), textprops={'fontsize': 8})
# Inner circle (donut hole)
center_circle = plt.Circle((0, 0), 0.3, color='white', fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
# Add title
plt.title('Distribution of Work Type')
# Show the plot
plt.show()
